# %% [markdown]
# ## Задание 1
# Для решения используем формулу:
#
# ![image.png](attachment:image.png)

# %%
sigma_0 = 16
m_vib = 80
n = 256
nad = 0.95 # альфа будет равна 0.05, тогда а/2 равна 0,025 из таблицы берем
z = 1.96 # из таблицы
left_ot = m_vib - z * 16 / pow(n, 0.5)
right_do = m_vib + z * 16 / pow(n, 0.5)
print("Доверительный интервал от", left_ot, 'до', right_do)
# Out:
# Доверительный интервал от 78.04 до 81.96

# %% [markdown]
# ## Задание 2
# Используем кооэфициент Стьюдента, так ка нет значения сигмы для генеральной совокупности

# %%
import numpy as np
x = [6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1]
dov_ver = 0.95
sigma = np.std(x, ddof=1)
arive = np.mean(x)
t = 26 # табличное значение коэффициента Стьюдента при доверительной вероятности 95% и степенью свободы =9
left_ot = arive - t * sigma / pow(n, 0.5)
right_do = arive + t * sigma / pow(n, 0.5)
print("Доверительный интервал от", left_ot, 'до', right_do)
# Out:
# Доверительный интервал от 5.417915437256244 до 7.762084562743757

# %% [markdown]
# ## Задание 3
#
# Проверим эту гипотезу, использую формулу:
#
# ![image.png](attachment:image.png)

# %%
m = 17
a = 0.05  # табличная величина соответствующая 1.65 сигмы
n = 100
m0 = 17.5
dis = 4
z =( m0-m )/(pow(4/100, 0.5))
if z < 1.65 :
    print ('Гипотеза верна')
else:
    print ('Гипотеза неверна')
z
# Out:
# Гипотеза неверна
# 2.5

# %% [markdown]
# ## Задание 4
#
# Найдем честность продавца

# %%
import numpy as np
m = 200
n = 10
x = [202, 203, 199, 197, 195, 201, 200, 204, 194, 190]
dov_ver = 0.99
sigma = np.std(x, ddof=1)
arive = np.mean(x)
z = (arive - 200)/(sigma/pow(n,0.5))
a_2 = 2.58  # табличное значение при 0.995
if abs(z) < a_2:
    print("Продавец говорит правду")
else:
    print("Продавец говорит лжет")

z
# Out:
# Продавец говорит правду
# -1.0651074037450896
